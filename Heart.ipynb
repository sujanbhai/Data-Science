# %% [markdown]
# #1. Import The Libraries And Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:\\heart.csv')

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# 2. Display Top 5 Rows of The Dataset#

# %%
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # 3. Check The Last 5 Rows of The Dataset

# %%
data.tail(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# #  4. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print('No of rows',data.shape[0])
print('No of columns',data.shape[1])
# Out:
# No of rows 1025
# No of columns 14

# %% [markdown]
# # 5. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # 6. Check Null Values In The Datase

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # 7. Check For Duplicate Data and Drop Them

# %%
dup=data.duplicated().any()
print('Any duplicate value',dup)
# Out:
# Any duplicate value True

# %%
dupl = data.drop_duplicates()
dupl
#print("Number of duplicate rows: ", dupl.shape[0])
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data=data.drop_duplicates()
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %% [markdown]
# # 8. Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # 9. Draw Correlation Matrix

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %% [markdown]
# # 10. How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?

# %%
data.sample(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 34    50    1   2       129   196    0        1      163      0      0.0
# 125   60    0   3       150   240    0        1      171      0      0.9
# 258   38    1   3       120   231    0        1      182      1      3.8
# 231   56    1   1       120   236    0        1      178      0      0.8
# 25    61    0   0       145   307    0        0      146      1      1.0
# 599   63    0   1       140   195    0        1      179      0      0.0
# 431   65    0   0       150   225    0        0      114      0      1.0
# 233   41    0   1       126   306    0        1      163      0      0.0
# 377   64    0   0       130   303    0        1      122      0      2.0
# 215   49    1   1       130   266    0        1      171      0      0.6
#
#      slope  ca  thal  target
# 34       2   0     2       1
# 125      2   0     2       1
# 258      1   0     3       0
# 231      2   0     2       1
# ...

# %%
#print((data['target']==0).sum())
#print((data['target']==1).sum())
#people with heart disease
data['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
df=data[data['target']==1]
df
#people with no heart disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5     58    0   0       100   248    0        0      122      0      1.0
# 10    71    0   0       112   149    0        1      125      0      1.6
# 12    34    0   1       118   210    0        1      192      0      0.7
# 16    51    0   2       140   308    0        0      142      0      1.5
# 18    50    0   1       120   244    0        1      162      0      1.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 691   55    0   1       135   250    0        0      161      0      1.4
# 708   60    0   2       120   178    1        1       96      0      0.0
# 719   52    1   0       108   233    1        1      147      0      0.1
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
#
#      slope  ca  thal  target
# 5        1   0     2       1
# 10       1   0     2       1
# ...

# %% [markdown]
# # 11. Find Count of Male & Female in this Dataset

# %%
#male
(data['sex']==0).sum()
# Out:
# 96

# %%
data['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
df.groupby('target')['sex'].value_counts()
# Out:
# target  sex
# 1       1      92
#         0      72
# Name: sex, dtype: int64

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5     58    0   0       100   248    0        0      122      0      1.0
# 10    71    0   0       112   149    0        1      125      0      1.6
# 12    34    0   1       118   210    0        1      192      0      0.7
# 16    51    0   2       140   308    0        0      142      0      1.5
# 18    50    0   1       120   244    0        1      162      0      1.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 691   55    0   1       135   250    0        0      161      0      1.4
# 708   60    0   2       120   178    1        1       96      0      0.0
# 719   52    1   0       108   233    1        1      147      0      0.1
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
#
#      slope  ca  thal  target
# 5        1   0     2       1
# 10       1   0     2       1
# ...

# %% [markdown]
# # 12. Find Gender Distribution According to The Target Variable

# %%
data.groupby('target')['sex'].value_counts()
# Out:
# target  sex
# 0       1      114
#         0       24
# 1       1       92
#         0       72
# Name: sex, dtype: int64

# %%
#countplot counts the number of occurence for each item
#hue used for sub-division inside the item
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='target', hue='sex', data=data)
#plt.xlabel('Heart')
plt.show()

# %%
#Find age Distribution According to The Target Variable
sns.countplot(x='target', hue='age', data=data)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %% [markdown]
# # 13. Check Age Distribution In The Dataset

# %%
data.groupby('age')['sex'].count()
# Out:
# age
# 29     1
# 34     2
# 35     4
# 37     2
# 38     2
# 39     4
# 40     3
# 41    10
# 42     8
# 43     8
# 44    11
# 45     8
# 46     7
# 47     5
# 48     7
# 49     5
# 50     7
# 51    12
# 52    13
# 53     8
# 54    16
# 55     8
# 56    11
# 57    17
# 58    19
# 59    14
# 60    11
# 61     8
# 62    11
# 63     9
# 64    10
# 65     8
# 66     7
# 67     9
# 68     4
# 69     3
# 70     4
# 71     3
# 74     1
# 76     1
# 77     1
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='age', hue='sex', data=data)
plt.show()

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='age', hue='target', data=data)
plt.show()

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.histplot(x='age',hue='target',kde=True, data=data)#kde for drawing line
#when hue is used counting is performed
plt.show()

# %% [markdown]
# # 14. Check Chest Pain Type#

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='cp', hue='target', data=data)
plt.show()

# %%
data['count']=1
data
data.groupby('cp').count()['count']
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_36928\2992518727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['count']=1
# cp
# 0    143
# 1     50
# 2     86
# 3     23
# Name: count, dtype: int64

# %% [markdown]
# #  15. Show The Chest Pain Distribution As Per Target Variable

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='target', hue='cp', data=data)
plt.show()

# %% [markdown]
# # 16. Show Fasting Blood Sugar Distribution According To Target Variable

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='target', hue='fbs', data=data)
plt.show()

# %% [markdown]
# # 17. Check Resting Blood Pressure Distribution

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='restecg', hue='sex', data=data)
plt.show()

# %%
data.groupby('restecg')['sex'].count()
# Out:
# restecg
# 0    147
# 1    151
# 2      4
# Name: sex, dtype: int64

# %%
data['restecg'].value_counts()
# Out:
# 1    151
# 0    147
# 2      4
# Name: restecg, dtype: int64

# %%
data.groupby(['restecg','sex'])['sex'].count()
# Out:
# restecg  sex
# 0        0       44
#          1      103
# 1        0       49
#          1      102
# 2        0        3
#          1        1
# Name: sex, dtype: int64

# %%
data.groupby('restecg')['sex'].value_counts()
# Out:
# restecg  sex
# 0        1      103
#          0       44
# 1        1      102
#          0       49
# 2        0        3
#          1        1
# Name: sex, dtype: int64

# %% [markdown]
# #  18. Compare Resting Blood Pressure As Per Sex Column

# %%
plt.figure(figsize=(16,8))#defining width and height
sns.countplot(x='sex', hue='restecg', data=data)
plt.show()

# %% [markdown]
# # 19. Show Distribution of Serum cholesterol

# %%
dsc=data.groupby(['chol','count'])['count'].count().reset_index()
dsc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36928\2106733349.py in <module>
# ----> 1 dsc=data.groupby(['chol','count'])['count'].count().reset_index()
#       2 dsc
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in reset_index(self, level, drop, name, inplace)
#    1492
#    1493             df = self.to_frame(name)
# -> 1494             return df.reset_index(level=level, drop=drop)
#    1495
#    1496     # ----------------------------------------------------------------------
#
# ...

# %%
dsc=data.groupby('chol')['count'].count().reset_index()
dsc

# %%
plt.figure(figsize=(15,8))#defining width and height
sns.lineplot(x='chol', y='count', data=dsc)
#plt.xticks(rotation=90)
plt.show()
