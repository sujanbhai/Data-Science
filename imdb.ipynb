# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\imdb.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# 1. Display Top 10 Rows of The Dataset
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
### 2. Check Last 10 Rows of The Dataset
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
print('No of row',data.shape[0])
print('No of column',data.shape[1])
# Out:
# No of row 1000
# No of column 12

# %%
### 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data[data['Rating']>8]
# Out:
#      Rank                                         Title  \
# 0       1                       Guardians of the Galaxy
# 6       7                                    La La Land
# 16     17                                 Hacksaw Ridge
# 18     19                                          Lion
# 26     27                       Bahubali: The Beginning
# 36     37                                  Interstellar
# 50     51    Star Wars: Episode VII - The Force Awakens
# 54     55                               The Dark Knight
# 64     65                                  The Prestige
# 67     68                            Mad Max: Fury Road
# 74     75                                      Zootopia
# 76     77                                  The Avengers
# 77     78                          Inglourious Basterds
# 80     81                                     Inception
# 82     83                       The Wolf of Wall Street
# 83     84                                     Gone Girl
# ...

# %%
### 5. Check Missing Values In The Dataset
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.isnull().sum()/len(data)*100
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
data[['Title','Rating','Metascore']]
# Out:
#                        Title  Rating  Metascore
# 0    Guardians of the Galaxy     8.1       76.0
# 1                 Prometheus     7.0       65.0
# 2                      Split     7.3       62.0
# 3                       Sing     7.2       59.0
# 4              Suicide Squad     6.2       40.0
# ..                       ...     ...        ...
# 995     Secret in Their Eyes     6.2       45.0
# 996          Hostel: Part II     5.5       46.0
# 997   Step Up 2: The Streets     6.2       50.0
# 998             Search Party     5.6       22.0
# 999               Nine Lives     5.3       11.0
#
# [1000 rows x 3 columns]

# %%
data[data['Rating']>=8]
# Out:
#      Rank                     Title                       Genre  \
# 0       1   Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 6       7                La La Land          Comedy,Drama,Music
# 16     17             Hacksaw Ridge     Biography,Drama,History
# 18     19                      Lion             Biography,Drama
# 19     20                   Arrival        Drama,Mystery,Sci-Fi
# ..    ...                       ...                         ...
# 742   743    El secreto de sus ojos       Drama,Mystery,Romance
# 765   766                        PK        Comedy,Drama,Romance
# 772   773  How to Train Your Dragon  Animation,Action,Adventure
# 861   862            Koe no katachi     Animation,Drama,Romance
# 991   992          Taare Zameen Par          Drama,Family,Music
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
sns.heatmap(data.isnull(),cmap='viridis',cbar=False,yticklabels=False,xticklabels=True)
plt.title('Missing data')
plt.show()

# %%
### 6. Drop All The  Missing Values
data.dropna(how='any',inplace=False)
#inplace=false display the result
#how=all drop row if all is null
#how=any drop row if at least one column is null
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.dropna(how='any',inplace=True)

# %%
data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
### 7. Check For Duplicate Data
dup=data.duplicated().any() #store boolean value
#whole row is similar in multiple places check by duplicated() function
print('any dupli value',dup)
# Out:
# any dupli value False

# %%
### 8. Get Overall Statistics About The DataFrame
data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
### 9. Display Title of The Movie Having Runtime >= 180 Minutes
#reset_index() for indexing
data[data['Runtime (Minutes)']>=180]['Title'].reset_index()
# Out:
#    index                    Title
# 0     82  The Wolf of Wall Street
# 1     88        The Hateful Eight
# 2    311           La vie d'Adèle

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.1+ KB

# %%
### 10. In Which Year There Was The Highest Average Voting?

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False).head(1)
# Out:
# Year
# 2012    290861.483871
# Name: Votes, dtype: float64

# %%
data.groupby('Year')['Votes'].mean()
# Out:
# Year
# 2006    277232.219512
# 2007    266530.704545
# 2008    266580.145833
# 2009    267180.577778
# 2010    261082.929825
# 2011    259254.736842
# 2012    290861.483871
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
plt.figure(figsize=(18,8))#defining width and height
sns.barplot(x='Year',y='Votes',data=data)
plt.show()

# %%
### 11. In Which Year There Was The Highest Average Revenue?
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False).head(1)
# Out:
# Year
# 2009    115.742
# Name: Revenue (Millions), dtype: float64

# %%
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    115.742000
# 2012    110.103065
# 2010    105.081579
# 2008     97.525417
# 2011     93.703333
# 2007     93.074091
# 2013     88.084643
# 2006     87.255610
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[(data['Runtime (Minutes)']>=180) & (data['Title']=='The Wolf of Wall Street')]
# Out:
#     Rank                    Title                   Genre  \
# 82    83  The Wolf of Wall Street  Biography,Comedy,Crime
#
#                                           Description         Director  \
# 82  Based on the true story of Jordan Belfort, fro...  Martin Scorsese
#
#                                                Actors  Year  \
# 82  Leonardo DiCaprio, Jonah Hill, Margot Robbie,M...  2013
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 82                180     8.2  865134              116.87       75.0

# %% [markdown]
# # Find The Average Rating For Each Director

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %%
data1=data.groupby('Director')['Rating'].mean().reset_index()
#reset_index() reseting index value
data1
# Out:
#                 Director  Rating
# 0             Aamir Khan    8.50
# 1    Abdellatif Kechiche    7.80
# 2             Adam McKay    7.00
# 3          Adam Shankman    6.30
# 4           Adam Wingard    5.90
# ..                   ...     ...
# 519         Xavier Dolan    8.10
# 520          Yimou Zhang    6.10
# 521     Yorgos Lanthimos    7.20
# 522          Zack Snyder    7.04
# 523        Zackary Adler    5.10
#
# [524 rows x 2 columns]

# %%
data1.sort_values(by='Rating',ascending=False).head(10)
# Out:
#                              Director  Rating
# 88                  Christopher Nolan    8.68
# 378                   Olivier Nakache    8.60
# 318                    Makoto Shinkai    8.60
# 154  Florian Henckel von Donnersmarck    8.50
# 0                          Aamir Khan    8.50
# 97                    Damien Chazelle    8.40
# 408                   Rajkumar Hirani    8.30
# 490                 Thomas Vinterberg    8.30
# 305                       Lee Unkrich    8.30
# 393                       Pete Docter    8.25

# %% [markdown]
# # Display Top 10 Lengthy Movies Title and Runtime

# %%
data['Runtime (Minutes)'].sort_values(ascending=False).head(10)
# Out:
# 88     187
# 82     180
# 311    180
# 267    172
# 430    170
# 75     169
# 36     169
# 271    169
# 425    166
# 126    165
# Name: Runtime (Minutes), dtype: int64

# %%
t10=data[['Title','Runtime (Minutes)']]
t10
# Out:
#                         Title  Runtime (Minutes)
# 0     Guardians of the Galaxy                121
# 1                  Prometheus                124
# 2                       Split                117
# 3                        Sing                108
# 4               Suicide Squad                123
# ..                        ...                ...
# 993  Resident Evil: Afterlife                 97
# 994                 Project X                 88
# 996           Hostel: Part II                 94
# 997    Step Up 2: The Streets                 98
# 999                Nine Lives                 87
#
# [838 rows x 2 columns]

# %%
t10.sort_values(by='Runtime (Minutes)',ascending=False).head(10)
# Out:
#                                         Title  Runtime (Minutes)
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 75   Pirates of the Caribbean: At World's End                169
# 36                               Interstellar                169
# 271         The Hobbit: An Unexpected Journey                169
# 425       The Curious Case of Benjamin Button                166
# 126           Transformers: Age of Extinction                165

# %%
data[['Title','Runtime (Minutes)']].sort_values(by='Runtime (Minutes)',ascending=False).head(10)
# Out:
#                                         Title  Runtime (Minutes)
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 75   Pirates of the Caribbean: At World's End                169
# 36                               Interstellar                169
# 271         The Hobbit: An Unexpected Journey                169
# 425       The Curious Case of Benjamin Button                166
# 126           Transformers: Age of Extinction                165

# %% [markdown]
# # Display Number of Movies Per Year

# %%
df=data.groupby('Year')['Title'].count().reset_index()
df
# Out:
#     Year  Title
# 0   2006     41
# 1   2007     44
# 2   2008     48
# 3   2009     45
# 4   2010     57
# 5   2011     57
# 6   2012     62
# 7   2013     84
# 8   2014     93
# 9   2015    109
# 10  2016    198

# %%
data['Year'].value_counts()
# Out:
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: Year, dtype: int64

# %%
plt.plot(df.Year,df.Title)
plt.show()

# %% [markdown]
# # Find Most Popular Movie Title (Higest Revenue)

# %%
data['Revenue (Millions)'].sort_values(ascending=False).head(10)
# Out:
# 50     936.63
# 87     760.51
# 85     652.18
# 76     623.28
# 54     533.32
# 12     532.17
# 119    486.29
# 94     458.99
# 124    448.13
# 578    424.65
# Name: Revenue (Millions), dtype: float64

# %%
data['Revenue (Millions)'].max()
# Out:
# 936.63

# %%
data['Revenue (Millions)'].idxmax()
# Out:
# 50

# %%
data.at[data['Revenue (Millions)'].idxmax(),'Title']
# Out:
# 'Star Wars: Episode VII - The Force Awakens'

# %%
#or
#condition required
data[data['Revenue (Millions)'].max()==data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# # Display Top 10 Highest Rated Movie Titles And its Directors

# %%
data['Rating'].sort_values(ascending=False).head(10)
# Out:
# 54     9.0
# 80     8.8
# 36     8.6
# 249    8.6
# 96     8.6
# 124    8.5
# 991    8.5
# 133    8.5
# 99     8.5
# 476    8.5
# Name: Rating, dtype: float64

# %%
data[['Title','Director','Rating']].sort_values(by='Rating',ascending=False).head(10)
# Out:
#                      Title                          Director  Rating
# 54         The Dark Knight                 Christopher Nolan     9.0
# 80               Inception                 Christopher Nolan     8.8
# 36            Interstellar                 Christopher Nolan     8.6
# 249       The Intouchables                   Olivier Nakache     8.6
# 96           Kimi no na wa                    Makoto Shinkai     8.6
# 124  The Dark Knight Rises                 Christopher Nolan     8.5
# 991       Taare Zameen Par                        Aamir Khan     8.5
# 133               Whiplash                   Damien Chazelle     8.5
# 99            The Departed                   Martin Scorsese     8.5
# 476    The Lives of Others  Florian Henckel von Donnersmarck     8.5

# %%
plt.figure(figsize=(18,8))
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Revenue (Millions)'>

# %%
### 17. Display Top 10 Highest Revenue Movie Titles
data[['Title','Revenue (Millions)']].sort_values(by='Revenue (Millions)',ascending=False).head(10)
# Out:
#                                           Title  Revenue (Millions)
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 87                                       Avatar              760.51
# 85                               Jurassic World              652.18
# 76                                 The Avengers              623.28
# 54                              The Dark Knight              533.32
# 12                                    Rogue One              532.17
# 119                                Finding Dory              486.29
# 94                      Avengers: Age of Ultron              458.99
# 124                       The Dark Knight Rises              448.13
# 578             The Hunger Games: Catching Fire              424.65

# %%
### 18. Find Average Rating of Movies Year Wise
data.groupby('Year')['Rating'].mean()
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2008    6.708333
# 2009    6.911111
# 2010    6.894737
# 2011    6.945614
# 2012    6.933871
# 2013    6.832143
# 2014    6.822581
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %%
### 19. Does Rating Affect The Revenue?
plt.scatter(x='Rating',y='Revenue (Millions)',data=data)

# %%
### 20. Classify Movies Based on Ratings [Excellent, Good and Average]
#dfr=data[['Title','Rating']]
#dfr
data.groupby('Rating')['Title'].count()
# Out:
# Rating
# 1.9     1
# 2.7     1
# 3.9     2
# 4.0     1
# 4.1     1
# 4.3     3
# 4.4     1
# 4.6     2
# 4.7     3
# 4.8     1
# 4.9     6
# 5.0     1
# 5.1     5
# 5.2     6
# 5.3     8
# 5.4    10
# 5.5    11
# 5.6    13
# 5.7    16
# 5.8    21
# 5.9    15
# 6.0    20
# 6.1    22
# 6.2    33
# 6.3    36
# 6.4    30
# 6.5    35
# 6.6    37
# 6.7    42
# 6.8    33
# 6.9    23
# 7.0    43
# 7.1    40
# 7.2    38
# 7.3    37
# 7.4    29
# 7.5    33
# 7.6    26
# 7.7    25
# 7.8    38
# 7.9    20
# 8.0    19
# 8.1    24
# 8.2     9
# 8.3     5
# 8.4     2
# 8.5     6
# 8.6     3
# 8.8     1
# 9.0     1
# Name: Title, dtype: int64
