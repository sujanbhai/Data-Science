# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:\\Salaries.csv')

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
data.sample(20)
# Out:
#             Id         EmployeeName                                 JobTitle  \
# 136556  136557    Alfredo O Mercado                   Patient Care Assistant
# 106955  106956   Timothy J Blomgren                        Transit Planner 2
# 103049  103050     Richard  Ferrari               Asst Materials Coordinator
# 120054  120055   Clifford J Schlink                           Deputy Sheriff
# 6864      6865         GREGORY KATS                               MANAGER II
# 143752  143753    Herlinda J Lozano                   Public Service Trainee
# 134551  134552        Betty L Reyes                             Senior Clerk
# 67148    67149      Martina Francis                             Senior Clerk
# 32971    32972         LOUISE LOPEZ  PUBLIC SAFETY COMMUNICATIONS DISPATCHER
# 8745      8746      MAXINE ANDERSON                          CLAIMS ADJUSTER
# 11309    11310           HARRY FONG                DIAGNOSTIC IMAGING TECH I
# ...

# %%
sns.regplot(x='TotalPay',y="TotalPayBenefits",data=data)
plt.show()

# %%
sns.residplot(data['BasePay'],data['TotalPayBenefits'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BasePay', ylabel='TotalPayBenefits'>

# %%
sns.residplot(data['OvertimePay'],data['TotalPayBenefits'])
# Out:
# <AxesSubplot:xlabel='OvertimePay', ylabel='TotalPayBenefits'>
