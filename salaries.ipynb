# %%
import pandas as pd

# %%
#load datasets
data=pd.read_csv('C:\\Salaries.csv')

# %%
#all columns
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
#describing all data
data.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
#datatypes
data.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
#same
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#top 20 data
data.head(20)
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
#data's rows and columns
data.shape
# Out:
# (148654, 13)

# %%
#random 20 data
data.sample(20)
# Out:
#             Id        EmployeeName                        JobTitle    BasePay  \
# 20670    20671        RILEY HUNTER               HEALTH WORKER III   57617.50
# 43926    43927      Judy Nishimoto     Electronic Maintenance Tech   98755.20
# 147733  147734        Eric M Colby  Events & Facilities Specialist    1260.50
# 19840    19841       MITCHELL KATZ               DEPARTMENT HEAD V   14949.61
# 18901    18902       SEAN PHILPOTT       TRAFFIC SURVEY TECHNICIAN   66037.74
# 46900    46901   Heather MacDonald          Performance Analyst II   94653.01
# 16538    16539      JAIME TIJERINO          EXECUTIVE SECRETARY II   72813.05
# 85157    85158        Mary K Brown                       Planner 3   95490.74
# 99368    99369  Rolando A Gonzalez                    Truck Driver   48829.78
# 28906    28907       LISA FAGUNDES                     LIBRARIAN I   22343.75
# 88111    88112       Fe V  Foronda       Licensed Vocational Nurse   73593.48
# ...

# %%
#top 5  sample data 
data.sample(200).head()
# Out:
#             Id          EmployeeName                        JobTitle  \
# 143166  143167       Alex C Riemondy  StdntDsgnTrain3, Arch/Eng/Plng
# 97537    97538          Jie Ting  Wu                          Porter
# 108732  108733  Reynaldo S Dela Vega                Transit Operator
# 124629  124630          John C Speer             IS Business Analyst
# 31226    31227            CANDICE YE            SENIOR ACCOUNT CLERK
#
#          BasePay  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# 143166  13233.21          0.0      0.00    132.33  13233.21          13365.54
# 97537   51641.01          0.0   2224.22  26398.84  53865.23          80264.07
# 108732   2042.51          0.0      0.00   1022.26   2042.51           3064.77
# 124629  93069.80          0.0      0.00  26039.99  93069.80         119109.79
# 31226   11316.00          0.0      0.00       NaN  11316.00          11316.00
#
#         Year  Notes         Agency  Status
# ...

# %%
#data columns
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
#no of rows and columns in dataset
print('no of columns',data.shape[0])
print('no of rows',data.shape[1])
# Out:
# no of columns 148654
# no of rows 13

# %%
#top 20 data of columns 'BasePay','OvertimePay','Benefits','TotalPay'
data[['BasePay','OvertimePay','Benefits','TotalPay']].head(20)
# Out:
#       BasePay  OvertimePay  Benefits   TotalPay
# 0   167411.18         0.00       NaN  567595.43
# 1   155966.02    245131.88       NaN  538909.28
# 2   212739.13    106088.18       NaN  335279.91
# 3    77916.00     56120.71       NaN  332343.61
# 4   134401.60      9737.00       NaN  326373.19
# 5   118602.00      8601.00       NaN  316285.74
# 6    92492.01     89062.90       NaN  315981.05
# 7   256576.96         0.00       NaN  307899.46
# 8   176932.64     86362.68       NaN  303427.55
# 9   285262.00         0.00       NaN  302377.73
# 10  194999.39     71344.88       NaN  299494.17
# 11   99722.00     87082.62       NaN  297608.92
# 12  294580.02         0.00       NaN  294580.02
# 13  271329.03         0.00       NaN  292671.62
# 14  174872.64     74050.30       NaN  286347.05
# 15  198778.01     73478.20       NaN  286213.86
# 16  268604.57         0.00       NaN  284720.43
# 17  140546.87    119397.26       NaN  278569.21
# 18  168692.63     69626.12       NaN  276434.22
# ...

# %%
#boolean result for null
data.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False     True         True      True
# 148651  False         False     False     True         True      True
# 148652  False         False     False     True         True      True
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
#total no of null data
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
data.isnull().count()
# Out:
# Id                  148654
# EmployeeName        148654
# JobTitle            148654
# BasePay             148654
# OvertimePay         148654
# OtherPay            148654
# Benefits            148654
# TotalPay            148654
# TotalPayBenefits    148654
# Year                148654
# Notes               148654
# Agency              148654
# Status              148654
# dtype: int64

# %%
#percentage of null data in dataset
X=data.isnull().sum()*100/len(data)

# %%
X
# Out:
# Id                    0.000000
# EmployeeName          0.000000
# JobTitle              0.000000
# BasePay               0.409676
# OvertimePay           0.002691
# OtherPay              0.002691
# Benefits             24.326961
# TotalPay              0.000000
# TotalPayBenefits      0.000000
# Year                  0.000000
# Notes               100.000000
# Agency                0.000000
# Status              100.000000
# dtype: float64

# %%
#drop columns ('Notes','Status','Agency') and store in data_drop. & axis=1 means column and axis=0 is row
data_drop=data.drop(columns=['Notes','Status','Agency'],axis=1)

# %%
#data 
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#data after droping columns
data_drop.head(20)
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
#grouping Total Pay in reference to Year and finding mean
data.groupby('Year')['TotalPay'].mean()
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64

# %%
#unique number find
data['JobTitle'].nunique()
# Out:
# 2159

# %%
data['JobTitle'].value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
#value count
data['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#add BasePay with OvertimePay then display only top 5
(data['BasePay']+data['OvertimePay']).head(5)
# Out:
# 0    167411.18
# 1    401097.90
# 2    318827.31
# 3    134036.71
# 4    144138.60
# dtype: float64

# %%
#unique data number
data.nunique()
# Out:
# Id                  148654
# EmployeeName        110811
# JobTitle              2159
# BasePay             109489
# OvertimePay          65998
# OtherPay             83225
# Benefits             98465
# TotalPay            138486
# TotalPayBenefits    142098
# Year                     4
# Notes                    0
# Agency                   1
# Status                   0
# dtype: int64

# %%
data.tail(200)
# Out:
#             Id      EmployeeName                     JobTitle  BasePay  \
# 148450  148451         Gabe Harp   BdComm Mbr, Grp2,M=$25/Mtg   200.00
# 148451  148452       Joshua Arce   BdComm Mbr, Grp2,M=$25/Mtg   200.00
# 148452  148453   Elinore E Lurie     Commissioner No Benefits   200.00
# 148453  148454      Lucia V Harp            Recreation Leader   199.41
# 148454  148455      Xue Yan Yang   Community Development Asst     0.00
# ...        ...               ...                          ...      ...
# 148645  148646  Carolyn A Wilson    Human Services Technician     0.00
# 148647  148648    Joann Anderson  Communications Dispatcher 2     0.00
# 148648  148649       Leon Walker                    Custodian     0.00
# 148649  148650     Roy I Tillery                    Custodian     0.00
# 148653  148654         Joe Lopez   Counselor, Log Cabin Ranch     0.00
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# ...
