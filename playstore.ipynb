# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:\\playstore.csv')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#find the avg no of reviews
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#searching if there is reviews with value 7M
data[data['Reviews']=='7.0M']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#replaces review with value 3.0M to 3.0
data['Reviews']=data['Reviews'].replace('3.0M',3.0)

# %%
data['Reviews'].dtypes
# Out:
# dtype('O')

# %%
data['Reviews']=data['Reviews'].astype('float')

# %%
data['Reviews'].dtypes
# Out:
# dtype('float64')

# %%
#find the no of free and paid app
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
data['Reviews']
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
#data having maxm reviews
data[data['Reviews'].max()==data['Reviews']]['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
data['Reviews'].mean()
# Out:
# 444111.9265750392

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
data['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
#replacing comma(,) in 'Installs' column by nothing i.e. removing comma and storing it in new column 'Install1' 
data['Install1']=data['Installs'].str.replace(',','')

# %%
#comma removed
data['Install1']
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: Install1, Length: 10841, dtype: object

# %%
#similarly removing plus(+) from column 'Install1' and updating within it
data['Install1']=data['Install1'].str.replace('+','')
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_30056\112150966.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Install1']=data['Install1'].str.replace('+','')

# %%
#plus removed
data['Install1']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Install1, Length: 10841, dtype: object

# %%
#checking if the column contain 'Free' as its value so as to convert it from object type to float
#if not removed can cause problem in type conversion
data[data['Install1']=='Free']
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      3.0
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone            NaN  11-Feb-18       1.0.19
#
#       Current Ver Android Ver Install1
# 10472  4.0 and up         NaN     Free

# %%
#replacing "Free" with zero
data["Install1"]=data["Install1"].str.replace('Free',"0")

# %%
#converting data type to int
data["Install1"]=data['Install1'].astype(int)

# %%
data['Install1'].dtypes
# Out:
# dtype('int32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Install1        10841 non-null  int32
# dtypes: float64(2), int32(1), object(11)
# memory usage: 1.1+ MB

# %%
#repacing dot(.) in below column by zero
#yetttikai gareko
data["Android Ver"]=data["Android Ver"].str.replace('.',"0")
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_30056\304138996.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Android Ver"]=data["Android Ver"].str.replace('.',"0")

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data["Android Ver"].dtypes
# Out:
# dtype('O')

# %%
data[data['Size']=='53M']
# Out:
#                                                      App             Category  \
# 492                         eharmony - Online Dating App               DATING
# 1001                                      Meme Generator        ENTERTAINMENT
# 1014                         Vivid Seats – Event Tickets               EVENTS
# 1165                      Bank of America Mobile Banking              FINANCE
# 1718                                    Garena Free Fire                 GAME
# 1742                                       Traffic Racer                 GAME
# 1810                      Word Crossy - A crossword game                 GAME
# 1915                                    Garena Free Fire                 GAME
# 1949                                    Garena Free Fire                 GAME
# 1976                                       Traffic Racer                 GAME
# 2070   Baby ABC in box! Kids alphabet games for toddl...               FAMILY
# ...

# %%
#removing M from column to change type to float
data['Size']=data['Size'].str.replace('M','')

# %%
data['Size']=data['Size'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30056\2639988719.py in <module>
# ----> 1 data['Size']=data['Size'].astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
#Varies with device raixa so tyo pani hataidim
data[data['Size']=='Varies with device']

# %%
data['Size']=data['Size'].str.replace('Varies with device','0')

# %%
data['Size']=data['Size'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30056\446790578.py in <module>
# ----> 1 data['Size']=data['Size'].astype('float')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
#201k raixa so
data['Size']=data['Size'].str.replace('k','000')

# %%
data['Size']=data['Size'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30056\446790578.py in <module>
# ----> 1 data['Size']=data['Size'].astype('float')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
#comma and plus
data["Size"]=data["Size"].str.replace(',',"")
data["Size"]=data["Size"].str.replace('+',"")
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_30056\976852015.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Size"]=data["Size"].str.replace('+',"")

# %%
data['Size']=data['Size'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30056\446790578.py in <module>
# ----> 1 data['Size']=data['Size'].astype('float')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
data['Size'].dtypes
# Out:
# dtype('O')

# %%
#58 index ma paila 201k value thyo tellai replace garera 201000 banako
data.at[58,'Size']
# Out:
# '201000'

# %%
data.sample(5)
# Out:
#                                App             Category  Rating  Reviews Size  \
# 1301    PumpUp — Fitness Community   HEALTH_AND_FITNESS     4.0  49479.0   57
# 7857             CT Scan Viewer 3D              MEDICAL     4.2      6.0   29
# 9244    AP Stamps and Registration  BOOKS_AND_REFERENCE     3.4     82.0  2.7
# 10390  Disney Princess Palace Pets               FAMILY     3.9  60097.0   19
# 10583      Florida Tides & Weather              WEATHER     3.8     30.0  2.0
#
#          Installs  Type   Price Content Rating                      Genres  \
# 1301   1,000,000+  Free       0           Teen            Health & Fitness
# 7857       1,000+  Free       0       Everyone                     Medical
# 9244      10,000+  Free       0       Everyone           Books & Reference
# 10390  1,000,000+  Free       0       Everyone  Entertainment;Pretend Play
# 10583      1,000+  Paid  $6.99        Everyone                     Weather
#
# ...

# %%
data.groupby('Rating')['Install1'].mean().reset_index()
# Out:
#     Rating      Install1
# 0      1.0  3.231250e+02
# 1      1.2  1.000000e+03
# 2      1.4  2.333333e+03
# 3      1.5  3.683333e+02
# 4      1.6  3.800000e+04
# 5      1.7  1.021250e+04
# 6      1.8  6.493750e+04
# 7      1.9  2.992308e+04
# 8      2.0  4.200125e+05
# 9      2.1  2.275000e+04
# 10     2.2  1.521857e+05
# 11     2.3  1.320500e+04
# 12     2.4  6.758421e+04
# 13     2.5  1.227667e+05
# 14     2.6  2.170400e+04
# 15     2.7  1.543920e+05
# 16     2.8  8.355119e+04
# 17     2.9  1.598022e+05
# 18     3.0  4.148660e+05
# 19     3.1  1.544326e+06
# 20     3.2  4.480375e+05
# 21     3.3  9.309000e+05
# 22     3.4  8.548043e+05
# 23     3.5  1.461534e+06
# 24     3.6  1.424815e+06
# 25     3.7  7.205232e+06
# 26     3.8  2.093969e+06
# 27     3.9  1.584731e+07
# 28     4.0  1.876856e+07
# 29     4.1  1.201301e+07
# 30     4.2  1.803592e+07
# 31     4.3  3.505054e+07
# 32     4.4  3.022520e+07
# 33     4.5  3.250675e+07
# 34     4.6  1.515379e+07
# 35     4.7  8.006764e+06
# ...

# %%
sns.lineplot(x=data['Rating'],y=data['Install1'])
plt.figure(figsize=(30,10))
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
sns.lineplot(x=data['Rating'],y=data['Install1'])
plt.subplot(212)
sns.lineplot(x=data['Rating'],y=data['Install1'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Install1'>

# %%
fig=plt.figure(figsize =(5, 4))
fig.add_axes([0.1, 0.1, 0.8, 0.8])
sns.lineplot(x=data['Rating'],y=data['Install1'])

fig.add_axes([0.5, 0.5, 0.3, 0.3])
sns.lineplot(x=data['Reviews'],y=data['Install1'])
# Out:
# <Axes:xlabel='Reviews', ylabel='Install1'>

# %%
plt.subplot2grid ((8, 2), (0, 0), rowspan = 2,  colspan = 1)
sns.lineplot(x=data['Rating'],y=data['Install1'])
plt.subplot2grid ((8, 2), (2, 1), rowspan = 2,  colspan = 1)
sns.lineplot(x=data['Reviews'],y=data['Install1'])
plt.subplot2grid ((8, 2), (5, 0), rowspan = 2,  colspan = 1)
sns.lineplot(x=data['Category'],y=data['Install1'])
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Install1'>

# %%
plt.figure(figsize =(5, 4))
sns.relplot(x=data['Rating'],y=data['Install1'])

# %%
sns.scatterplot(x=data['Type'],y=data['Install1'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Install1'>

# %%
sns.scatterplot(x=data['Rating'],y=data['Install1'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Install1'>

# %%
sns.residplot(x=data['Rating'],y=data['Install1'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Install1'>

# %%
plt.figure(figsize=(18,9))
sns.barplot(x=data['Rating'],y=data['Install1'])
plt.show()

# %%
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
sns.countplot(x='Category', data=data)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.boxplot(x='Type', y='Rating', data=data,hue='Type')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.violinplot(x='Install1', y='Rating', data=data)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.stripplot(x='Rating', y='Install1', data=data)
plt.show()

# %%
#same as  strip but no overlap occur
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.swarmplot(x='Type', y='Rating', data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30056\2660210009.py in <module>
#       2 plt.figure(figsize=(20,10))
#       3 plt.xticks(rotation=90)
# ----> 4 sns.swarmplot(x='Type', y='Rating', data=data)
#       5 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    3017                        linewidth=linewidth))
#    3018
# -> 3019     plotter.plot(ax, kwargs)
#    3020     return ax
#    3021
#
# ...
