# %%
import pandas as pd

# %%
data=pd.read_csv('C:\purchase_data_exe.csv')

# %%
data.columns
# Out:
# Index(['date', 'customer_id', 'product_category', 'payment_method',
#        'value [USD]', 'time_on_site [Minutes]', 'clicks_in_site',
#        'Unnamed: 7'],
#       dtype='object')

# %%
data.head()
# Out:
#          date  customer_id  product_category payment_method  value [USD]  \
# 0  20/11/2018        37077               505         credit        49.53
# 1  20/11/2018        59173               509         paypal        50.61
# 2  20/11/2018        41066               507         credit        85.99
# 3  20/11/2018        50741               506         credit        34.60
# 4  20/11/2018        53639               515         paypal       266.27
#
#    time_on_site [Minutes]  clicks_in_site  Unnamed: 7
# 0                    12.0               8         NaN
# 1                    25.9               8         NaN
# 2                    34.9              11         NaN
# 3                    16.5               9         NaN
# 4                    43.1              30         NaN

# %%
data.head(10)
# Out:
#          date  customer_id  product_category payment_method  value [USD]  \
# 0  20/11/2018        37077               505         credit        49.53
# 1  20/11/2018        59173               509         paypal        50.61
# 2  20/11/2018        41066               507         credit        85.99
# 3  20/11/2018        50741               506         credit        34.60
# 4  20/11/2018        53639               515         paypal       266.27
# 5  20/11/2018        39783               501         credit       193.78
# 6  20/11/2018        26767               514         paypal        61.22
# 7  20/11/2018        20719               505         paypal        11.18
# 8  20/11/2018        46947               515         paypal       144.01
# 9  20/11/2018        31839               512         credit       447.92
#
#    time_on_site [Minutes]  clicks_in_site  Unnamed: 7
# 0                    12.0               8         NaN
# 1                    25.9               8         NaN
# ...

# %%
data.head(50)
# Out:
#           date  customer_id  product_category payment_method  value [USD]  \
# 0   20/11/2018        37077               505         credit        49.53
# 1   20/11/2018        59173               509         paypal        50.61
# 2   20/11/2018        41066               507         credit        85.99
# 3   20/11/2018        50741               506         credit        34.60
# 4   20/11/2018        53639               515         paypal       266.27
# 5   20/11/2018        39783               501         credit       193.78
# 6   20/11/2018        26767               514         paypal        61.22
# 7   20/11/2018        20719               505         paypal        11.18
# 8   20/11/2018        46947               515         paypal       144.01
# 9   20/11/2018        31839               512         credit       447.92
# 10  20/11/2018        22249               509         paypal       144.87
# 11  20/11/2018        15109               512         credit       102.76
# ...

# %%
data.tail() #to look f
# Out:
#              date  customer_id  product_category payment_method  value [USD]  \
# 24994  29/11/2018        33699               513         credit        55.89
# 24995  29/11/2018        38652               501         paypal       136.27
# 24996  29/11/2018        30222               504         paypal       427.45
# 24997  29/11/2018        30183               507         credit       981.81
# 24998  29/11/2018        46662               505         credit         6.10
#
#        time_on_site [Minutes]  clicks_in_site  Unnamed: 7
# 24994                    45.1               7         NaN
# 24995                    61.0              11         NaN
# 24996                    52.8              45         NaN
# 24997                    58.2              76         NaN
# 24998                    47.2               6         NaN

# %%
data.head(-5)
# Out:
#              date  customer_id  product_category payment_method  value [USD]  \
# 0      20/11/2018        37077               505         credit        49.53
# 1      20/11/2018        59173               509         paypal        50.61
# 2      20/11/2018        41066               507         credit        85.99
# 3      20/11/2018        50741               506         credit        34.60
# 4      20/11/2018        53639               515         paypal       266.27
# ...           ...          ...               ...            ...          ...
# 24989  29/11/2018        39497               514         credit        32.49
# 24990  29/11/2018        48796               506         credit        35.02
# 24991  29/11/2018        49889               507         credit       172.13
# 24992  29/11/2018        14183               510         paypal       484.08
# 24993  29/11/2018        13979               502         paypal       116.90
#
# ...

# %%
data.shape
# Out:
# (24999, 8)

# %%
data.tail(-5) #if we assign no in method ie (-5) in tail it shows both first 5 and last 5 here starting with 5-9 and last
# Out:
#              date  customer_id  product_category payment_method  value [USD]  \
# 5      20/11/2018        39783               501         credit       193.78
# 6      20/11/2018        26767               514         paypal        61.22
# 7      20/11/2018        20719               505         paypal        11.18
# 8      20/11/2018        46947               515         paypal       144.01
# 9      20/11/2018        31839               512         credit       447.92
# ...           ...          ...               ...            ...          ...
# 24994  29/11/2018        33699               513         credit        55.89
# 24995  29/11/2018        38652               501         paypal       136.27
# 24996  29/11/2018        30222               504         paypal       427.45
# 24997  29/11/2018        30183               507         credit       981.81
# 24998  29/11/2018        46662               505         credit         6.10
#
# ...

# %%
data.shape  #row , column
# Out:
# (24999, 8)

# %%
#here we have no of rows and columns counted 
print("Number of row",data.shape[0])
print("Number of column",data.shape[1])
# Out:
# Number of row 24999
# Number of column 8

# %%
data.describe() # this describes only numerical values
# Out:
#         customer_id  product_category   value [USD]  time_on_site [Minutes]  \
# count  24999.000000      24999.000000  24999.000000            24999.000000
# mean   35047.126765        507.918797    203.248763               73.132649
# std    14448.792961          4.288552    208.015747              150.983919
# min    10000.000000        501.000000      0.000000                2.000000
# 25%    22500.000000        504.000000     57.170000               13.300000
# 50%    35184.000000        508.000000    136.720000               24.100000
# 75%    47468.000000        512.000000    278.815000               43.000000
# max    59998.000000        515.000000   2177.040000              655.000000
#
#        clicks_in_site  Unnamed: 7
# count    24999.000000         0.0
# mean        16.039642         NaN
# std         13.396365         NaN
# min          0.000000         NaN
# 25%          8.000000         NaN
# 50%         11.000000         NaN
# 75%         19.000000         NaN
# ...

# %%
data.describe(include='all') #here all the columns are described
# Out:
#               date   customer_id  product_category payment_method  \
# count        24999  24999.000000      24999.000000          24999
# unique          10           NaN               NaN              2
# top     23/11/2018           NaN               NaN         credit
# freq          7292           NaN               NaN          14459
# mean           NaN  35047.126765        507.918797            NaN
# std            NaN  14448.792961          4.288552            NaN
# min            NaN  10000.000000        501.000000            NaN
# 25%            NaN  22500.000000        504.000000            NaN
# 50%            NaN  35184.000000        508.000000            NaN
# 75%            NaN  47468.000000        512.000000            NaN
# max            NaN  59998.000000        515.000000            NaN
#
#          value [USD]  time_on_site [Minutes]  clicks_in_site  Unnamed: 7
# count   24999.000000            24999.000000    24999.000000         0.0
# ...

# %%
data.info() #formats of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24999 entries, 0 to 24998
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    24999 non-null  object
#  1   customer_id             24999 non-null  int64
#  2   product_category        24999 non-null  int64
#  3   payment_method          24999 non-null  object
#  4   value [USD]             24999 non-null  float64
#  5   time_on_site [Minutes]  24999 non-null  float64
#  6   clicks_in_site          24999 non-null  int64
#  7   Unnamed: 7              0 non-null      float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.5+ MB

# %%
data.mean()
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_2744\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# customer_id               35047.126765
# product_category            507.918797
# value [USD]                 203.248763
# time_on_site [Minutes]       73.132649
# clicks_in_site               16.039642
# Unnamed: 7                         NaN
# dtype: float64

# %%
data['customer_id'].max() #individual work of a particular column
# Out:
# 59998

# %%
data['customer_id'].min()
# Out:
# 10000

# %%
data['customer_id'].std()  #standard deviation
# Out:
# 14448.792960921464

# %%
data.dtypes
# Out:
# date                       object
# customer_id                 int64
# product_category            int64
# payment_method             object
# value [USD]               float64
# time_on_site [Minutes]    float64
# clicks_in_site              int64
# Unnamed: 7                float64
# dtype: object

# %%
data['date'].dtypes #single dtype describe
# Out:
# dtype('O')

# %%
data.isnull()
# Out:
#         date  customer_id  product_category  payment_method  value [USD]  \
# 0      False        False             False           False        False
# 1      False        False             False           False        False
# 2      False        False             False           False        False
# 3      False        False             False           False        False
# 4      False        False             False           False        False
# ...      ...          ...               ...             ...          ...
# 24994  False        False             False           False        False
# 24995  False        False             False           False        False
# 24996  False        False             False           False        False
# 24997  False        False             False           False        False
# 24998  False        False             False           False        False
#
#        time_on_site [Minutes]  clicks_in_site  Unnamed: 7
# ...

# %%
data.isnull().head(100)
# Out:
#      date  customer_id  product_category  payment_method  value [USD]  \
# 0   False        False             False           False        False
# 1   False        False             False           False        False
# 2   False        False             False           False        False
# 3   False        False             False           False        False
# 4   False        False             False           False        False
# ..    ...          ...               ...             ...          ...
# 95  False        False             False           False        False
# 96  False        False             False           False        False
# 97  False        False             False           False        False
# 98  False        False             False           False        False
# 99  False        False             False           False        False
#
#     time_on_site [Minutes]  clicks_in_site  Unnamed: 7
# 0                    False           False        True
# ...

# %%
data.isnull().sum()  #count if null values available
# Out:
# date                          0
# customer_id                   0
# product_category              0
# payment_method                0
# value [USD]                   0
# time_on_site [Minutes]        0
# clicks_in_site                0
# Unnamed: 7                24999
# dtype: int64

# %%
data.isnull().count() #count no of values
# Out:
# date                      24999
# customer_id               24999
# product_category          24999
# payment_method            24999
# value [USD]               24999
# time_on_site [Minutes]    24999
# clicks_in_site            24999
# Unnamed: 7                24999
# dtype: int64

# %%
len(data) #total data
# Out:
# 24999
