# %%
import pandas as pd
import seaborn as sns #generate diagram
import matplotlib.pyplot as plt #to decorate

# %%
#load datasets
data=pd.read_csv('C:\\Salaries.csv')

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#displot for bar diagram
#kde kernel density estimate plot
#kde=False displays histogram only
#kde=True displays histogram along with the line 
#bins means no of bins in the histogram
#aspect means ratio of width to the height
#margins is used for initiation point to the histogram
sns.displot(data['TotalPayBenefits'],kde=True,bins=20,aspect=5)

#sns.displot(data['TotalPayBenefits'],kde=False,bins=100,aspect=5)
plt.margins(x=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#change data type from lower to higher
data['Year']=data['Year'].astype('float')

# %%
data['Year'].dtypes
# Out:
# dtype('float64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  float64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 14.7+ MB

# %%
data['Year']=data['Year'].astype('int')

# %%
data['Year'].dtypes
# Out:
# dtype('int32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int32
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int32(1), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
#changing data type from higher to lower is not supported
data['OtherPay']=data['OtherPay'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20992\3490376470.py in <module>
#       1 #changing data type from higher to lower is not supported
# ----> 2 data['OtherPay']=data['OtherPay'].astype('int')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
data['EmployeeName']=="Not provided"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650     True
# 148651     True
# 148652     True
# 148653    False
# Name: EmployeeName, Length: 148654, dtype: bool

# %%
#data.loc allows to access and modify data in the DataFrame
data.loc[data['EmployeeName']=="Not provided"].head(2)
# Out:
#             Id  EmployeeName      JobTitle  BasePay  OvertimePay  OtherPay  \
# 148646  148647  Not provided  Not provided      NaN          NaN       NaN
# 148650  148651  Not provided  Not provided      NaN          NaN       NaN
#
#         Benefits  TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 148646       NaN       0.0               0.0  2014    NaN  San Francisco
# 148650       NaN       0.0               0.0  2014    NaN  San Francisco
#
#         Status
# 148646     NaN
# 148650     NaN

# %%
#sameeee
data[data['EmployeeName']=="Not provided"].head(2)
# Out:
#             Id  EmployeeName      JobTitle  BasePay  OvertimePay  OtherPay  \
# 148646  148647  Not provided  Not provided      NaN          NaN       NaN
# 148650  148651  Not provided  Not provided      NaN          NaN       NaN
#
#         Benefits  TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 148646       NaN       0.0               0.0  2014    NaN  San Francisco
# 148650       NaN       0.0               0.0  2014    NaN  San Francisco
#
#         Status
# 148646     NaN
# 148650     NaN

# %%
data=data[data['EmployeeName']!="Not provided"]
data.reset_index()
# Out:
#          index      Id       EmployeeName  \
# 0            0       1     NATHANIEL FORD
# 1            1       2       GARY JIMENEZ
# 2            2       3     ALBERT PARDINI
# 3            3       4  CHRISTOPHER CHONG
# 4            4       5    PATRICK GARDNER
# ...        ...     ...                ...
# 148645  148645  148646   Carolyn A Wilson
# 148646  148647  148648     Joann Anderson
# 148647  148648  148649        Leon Walker
# 148648  148649  148650      Roy I Tillery
# 148649  148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...

# %%
data.describe(exclude='number')
# Out:
#        EmployeeName          JobTitle         Agency
# count        148650            148650         148650
# unique       110810              2158              1
# top       Kevin Lee  Transit Operator  San Francisco
# freq             13              7036         148650

# %%
#total no of job title contain captain
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
#length of data containing 'captain' as JobTltle
len(data[data['JobTitle'].str.contains('captain',case=False)])
# Out:
# 552

# %%
#display all employee name fron fire department
data['JobTitle'].str.contains('fire department',case=False)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: JobTitle, Length: 148650, dtype: bool

# %%
#here
data[data['JobTitle'].str.contains('fire department',case=False)][['EmployeeName','JobTitle']]
# Out:
#                 EmployeeName                                          JobTitle
# 4            PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 6                  ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 8             MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9         JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10             ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...                      ...                                               ...
# 32623           JAMES BARDEN                BATTALION CHIEF, (FIRE DEPARTMENT)
# 36162     Joanne Hayes-White                            Chief, Fire Department
# 72926   Joanne M Hayes-White                            Chief, Fire Department
# 102303        Robert E Evans                        Captain, (Fire Department)
# 110535  Joanne M Hayes-White                            Chief, Fire Department
#
# [226 rows x 2 columns]

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148645                       Human Services Technician       0.00
# ...

# %%
data.at[148646,'EmployeeName']
# Out:
# 'Not provided'
