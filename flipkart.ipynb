# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:\\flipkart_laptops.csv',encoding='latin1')

# %%
data
# Out:
#                                                   Name   Brand  Selling Price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  Lenovo          36990
# 1    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  Lenovo          37990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ASUS          32990
# 3    realme Book (Slim) Core i3 11th Gen - (8 GB/25...  realme          46990
# 4    DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL          38990
# ..                                                 ...     ...            ...
# 409  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL          45890
# 410  acer Swift 3 Core i5 11th Gen Intel EVO - (8 G...    acer          68500
# 411  HP Pavilion Ryzen 7 Octa Core AMD R7-5800H - (...      HP          90000
# 412  ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 G...    ASUS          44490
# 413  DELL Inspiron Core i5 11th Gen - (8 GB/1 TB HD...    DELL          65990
#
# ...

# %%
data['Discount']=data['Discount'].str.replace('% off','')

# %%
data
# Out:
#                                                   Name   Brand  Selling Price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  Lenovo          36990
# 1    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  Lenovo          37990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ASUS          32990
# 3    realme Book (Slim) Core i3 11th Gen - (8 GB/25...  realme          46990
# 4    DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL          38990
# ..                                                 ...     ...            ...
# 409  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    DELL          45890
# 410  acer Swift 3 Core i5 11th Gen Intel EVO - (8 G...    acer          68500
# 411  HP Pavilion Ryzen 7 Octa Core AMD R7-5800H - (...      HP          90000
# 412  ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 G...    ASUS          44490
# 413  DELL Inspiron Core i5 11th Gen - (8 GB/1 TB HD...    DELL          65990
#
# ...

# %%
data['Ratings'].dtypes
# Out:
# dtype('float64')

# %%
data['Ratings']
# Out:
# 0      4.2
# 1      4.2
# 2      4.3
# 3      4.4
# 4      4.3
#       ...
# 409    4.3
# 410    4.4
# 411    4.6
# 412    4.4
# 413    4.3
# Name: Ratings, Length: 414, dtype: float64

# %%
dataB=data.groupby("Brand").mean()
dataB
# Out:
#            Selling Price            MRP   Ratings
# Brand
# ALIENWARE  224995.000000  258201.000000  4.450000
# APPLE      155384.736842  166957.368421  4.631579
# ASUS        72996.233333   97087.650000  4.381667
# DELL        55861.642857   70963.842857  4.174286
# HP          65208.015873   78008.603175  4.176190
# Infinix     36847.142857   56423.714286  4.221429
# Lenovo      55254.440678   77961.796610  4.203390
# MICROSOFT   99990.000000  124999.000000  3.800000
# MSI         91490.454545  119808.181818  4.368182
# Mi          39990.000000   46359.000000  4.400000
# Nokia       50323.333333   85326.666667  4.133333
# RedmiBook   31990.000000   51999.000000  4.200000
# SAMSUNG     59990.000000   79990.000000  4.600000
# Vaio        50656.666667   73056.666667  3.866667
# acer        67042.000000   89467.906250  4.312500
# lenovo     102990.000000  139890.000000  4.700000
# realme      53490.000000   62499.000000  4.400000

# %%
#benefits with column
dataB=data.groupby('Brand')['Ratings','MRP'].mean().reset_index()
dataB
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_26488\2822347304.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dataB=data.groupby('Brand')['Ratings','MRP'].mean().reset_index()
#         Brand   Ratings            MRP
# 0   ALIENWARE  4.450000  258201.000000
# 1       APPLE  4.631579  166957.368421
# 2        ASUS  4.381667   97087.650000
# 3        DELL  4.174286   70963.842857
# 4          HP  4.176190   78008.603175
# 5     Infinix  4.221429   56423.714286
# 6      Lenovo  4.203390   77961.796610
# 7   MICROSOFT  3.800000  124999.000000
# 8         MSI  4.368182  119808.181818
# 9          Mi  4.400000   46359.000000
# 10      Nokia  4.133333   85326.666667
# 11  RedmiBook  4.200000   51999.000000
# 12    SAMSUNG  4.600000   79990.000000
# 13       Vaio  3.866667   73056.666667
# 14       acer  4.312500   89467.906250
# 15     lenovo  4.700000  139890.000000
# ...

# %%
dataB['MRP']=dataB['MRP'].astype(float)

# %%
plt.figure(figsize=(18,8))
sns.barplot(x='Brand',y='Ratings',data=dataB,color='pink')
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(x='Brand',y='Ratings',data=data)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           414 non-null    object
#  1   Brand          414 non-null    object
#  2   Selling Price  414 non-null    int64
#  3   MRP            414 non-null    int64
#  4   Discount       414 non-null    object
#  5   Ratings        414 non-null    float64
#  6   No_of_ratings  414 non-null    object
#  7   Details        414 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 26.0+ KB
