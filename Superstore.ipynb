# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Superstore.csv")

# %%
data.sample(30)
# Out:
#            Ship Mode      Segment        Country           City  \
# 2120  Standard Class     Consumer  United States   Ormond Beach
# 1229  Standard Class     Consumer  United States    Los Angeles
# 503   Standard Class    Corporate  United States         Parker
# 3528  Standard Class     Consumer  United States      San Diego
# 6804     First Class     Consumer  United States         Pomona
# 2805  Standard Class     Consumer  United States        El Paso
# 9981     First Class     Consumer  United States      Fairfield
# 151      First Class  Home Office  United States     Scottsdale
# 6289    Second Class  Home Office  United States          Chico
# 4555     First Class     Consumer  United States       Florence
# 7566     First Class    Corporate  United States        Houston
# 4705     First Class     Consumer  United States      Waterbury
# 1279     First Class    Corporate  United States          Macon
# 8734    Second Class    Corporate  United States        Seattle
# ...

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.groupby('City')['Segment'].count()
# Out:
# City
# Aberdeen        1
# Abilene         1
# Akron          21
# Albuquerque    14
# Alexandria     16
#                ..
# Woonsocket      4
# Yonkers        15
# York            5
# Yucaipa         1
# Yuma            4
# Name: Segment, Length: 531, dtype: int64

# %%
data[['Category','Sub-Category']]
# Out:
#              Category Sub-Category
# 0           Furniture    Bookcases
# 1           Furniture       Chairs
# 2     Office Supplies       Labels
# 3           Furniture       Tables
# 4     Office Supplies      Storage
# ...               ...          ...
# 9989        Furniture  Furnishings
# 9990        Furniture  Furnishings
# 9991       Technology       Phones
# 9992  Office Supplies        Paper
# 9993  Office Supplies   Appliances
#
# [9994 rows x 2 columns]

# %%
data['Cat']=data[data['Category'].str.contains('Furniture',case=False)]['Sub-Category']
data['Cat']
# Out:
# 0         Bookcases
# 1            Chairs
# 2               NaN
# 3            Tables
# 4               NaN
#            ...
# 9989    Furnishings
# 9990    Furnishings
# 9991            NaN
# 9992            NaN
# 9993            NaN
# Name: Cat, Length: 9994, dtype: object

# %%
data['Cat'].value_counts()
# Out:
# Furnishings    957
# Chairs         617
# Tables         319
# Bookcases      228
# Name: Cat, dtype: int64

# %%
data.sample(30)
# Out:
#            Ship Mode      Segment        Country           City  \
# 4543    Second Class     Consumer  United States        Chicago
# 6519  Standard Class     Consumer  United States  San Francisco
# 4007  Standard Class     Consumer  United States        Roswell
# 8638     First Class  Home Office  United States        Kenosha
# 3569        Same Day  Home Office  United States        Seattle
# 403   Standard Class    Corporate  United States     Wilmington
# 666     Second Class    Corporate  United States         Dallas
# 8661  Standard Class     Consumer  United States        Houston
# 616     Second Class    Corporate  United States  New York City
# 9092    Second Class    Corporate  United States           Troy
# 7194     First Class     Consumer  United States        Atlanta
# 3253    Second Class  Home Office  United States        Chicago
# 5862    Second Class     Consumer  United States    Little Rock
# 195   Standard Class     Consumer  United States       Hamilton
# ...

# %%
sns.scatterplot(x=data['Sales'],y=data['Profit'],hue=data['Segment'])
plt.show()

# %%
sns.lineplot(x=data['Sales'],y=data['Profit'],hue=data['Segment'])
plt.show()

# %%
sns.barplot(x=data['Ship Mode'],y=data['Sales'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>
